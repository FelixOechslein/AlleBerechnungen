# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import scipy.stats as stats
import math
import seaborn as sns
from datetime import datetime, timedelta
from scipy.stats import pearsonr
from scipy.stats import kendalltau
from scipy.stats import spearmanr

# %%
df_transactions_wofirstname = pd.read_csv("C:/Users/felix.oechslein/Desktop/Daten, 13.12.22/Rohdaten/" +
                                    "ELPHI_transactions_ohne_vorname.csv")

df_history_wofirstname = pd.read_csv("C:/Users/felix.oechslein/Desktop/Daten, 13.12.22/Rohdaten/" +
                                    "ELPHI_history_ohne_vorname.csv")
# Out:
# C:\Users\felix.oechslein\AppData\Local\Temp\ipykernel_7476\3453601399.py:1: DtypeWarning: Columns (13,15,16,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_transactions_wofirstname = pd.read_csv("C:/Users/felix.oechslein/Desktop/Daten, 13.12.22/Rohdaten/" +

# %%
df_test = df_history_wofirstname.head(1000)

# %%
df_test.head(10)
# Out:
#     mandator         id        iid attrtype       akey  \
# 0  174363396  264631559  165888639       NO  262370023
# 1  174363396  264631563  172138098       NO  262370023
# 2  174363396  284963773  186134667       NO  284155779
# 3  174363396  264631564  175952454       NO  262370023
# 4  174363396  264631565  180175750       NO  262370023
# 5  174363396  264631568  172857316       NO  262370023
# 6  174363396  264631566  175064705       NO  262370023
# 7  174363396  284963781  175279065       NO  283853037
# 8  174363396  264631567  175064705       NO  262370023
# 9  174363396  264631570  186796746       NO  262370023
#
#                                                 text        creation
# 0  |msg=2122 NL Konzerte 220712 Afrofuturism|user...  20220714001502
# 1  |msg=2122 NL Konzerte 220712 Afrofuturism|user...  20220714001511
# 2  |msg=2223 NL Konzerte 221115 Empfehlungen Deze...  20221117073119
# 3  |msg=2122 NL Konzerte 220712 Afrofuturism|user...  20220714001511
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mandator  1000 non-null   int64
#  1   id        1000 non-null   int64
#  2   iid       1000 non-null   int64
#  3   attrtype  1000 non-null   object
#  4   akey      1000 non-null   int64
#  5   text      1000 non-null   object
#  6   creation  1000 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 54.8+ KB

# %%
neueSpalten = [ line.strip().split('|') for line in df_test["text"] ]
print(neueSpalten)
# Out:
# [['', 'msg=2122 NL Konzerte 220712 Afrofuturism', 'userAgent=unknown (unknown / Personal computer)', 'hidden=true', 'ip=104.28.62.43', 'userLanguage=de', ''], ['', 'msg=2122 NL Konzerte 220712 Afrofuturism', 'userAgent=unknown (unknown / Personal computer)', 'hidden=true', 'ip=104.28.129.15', 'userLanguage=de', ''], ['', 'msg=2223 NL Konzerte 221115 Empfehlungen Dezember - Variante 1', 'hidden=true', 'fullUserAgent=Mozilla/5.0', 'ip=104.28.62.41', 'userAgent=unknown (unknown / Personal computer)', 'userLanguage=de', ''], ['', 'msg=2122 NL Konzerte 220712 Afrofuturism', 'userAgent=unknown (unknown / Personal computer)', 'hidden=true', 'ip=172.225.190.192', 'userLanguage=de', ''], ['', 'msg=2122 NL Konzerte 220712 Afrofuturism', 'userAgent=unknown (unknown / Personal computer)', 'hidden=true', 'ip=104.28.42.15', 'userLanguage=de', ''], ['', 'msg=2122 NL Konzerte 220712 Afrofuturism', 'userAgent=unknown (unknown / Personal computer)', 'hidden=true', 'ip=104.28.34.143', 'userLanguage=de'
# ...

# %%
df_neueSpalte = pd.DataFrame(neueSpalten)
df_neueSpalte.head()
# Out:
#   0                                                  1   \
# 0              msg=2122 NL Konzerte 220712 Afrofuturism
# 1              msg=2122 NL Konzerte 220712 Afrofuturism
# 2     msg=2223 NL Konzerte 221115 Empfehlungen Dezem...
# 3              msg=2122 NL Konzerte 220712 Afrofuturism
# 4              msg=2122 NL Konzerte 220712 Afrofuturism
#
#                                                 2                          3   \
# 0  userAgent=unknown (unknown / Personal computer)                hidden=true
# 1  userAgent=unknown (unknown / Personal computer)                hidden=true
# 2                                      hidden=true  fullUserAgent=Mozilla/5.0
# 3  userAgent=unknown (unknown / Personal computer)                hidden=true
# 4  userAgent=unknown (unknown / Personal computer)                hidden=true
#
#                    4                                                5   \
# 0     ip=104.28.62.43                                  userLanguage=de
# ...

# %%
df_neueSpalte.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1000 non-null   object
#  1   1       1000 non-null   object
#  2   2       1000 non-null   object
#  3   3       1000 non-null   object
#  4   4       1000 non-null   object
#  5   5       1000 non-null   object
#  6   6       999 non-null    object
#  7   7       870 non-null    object
#  8   8       291 non-null    object
#  9   9       245 non-null    object
#  10  10      245 non-null    object
#  11  11      245 non-null    object
#  12  12      245 non-null    object
#  13  13      245 non-null    object
#  14  14      245 non-null    object
#  15  15      9 non-null      object
#  16  16      9 non-null      object
#  17  17      9 non-null      object
#  18  18      9 non-null      object
# dtypes: object(19)
# memory usage: 148.6+ KB

# %%
df_neueSpalte.head(50)
# Out:
#    0                                                  1   \
# 0               msg=2122 NL Konzerte 220712 Afrofuturism
# 1               msg=2122 NL Konzerte 220712 Afrofuturism
# 2      msg=2223 NL Konzerte 221115 Empfehlungen Dezem...
# 3               msg=2122 NL Konzerte 220712 Afrofuturism
# 4               msg=2122 NL Konzerte 220712 Afrofuturism
# 5               msg=2122 NL Konzerte 220712 Afrofuturism
# 6               msg=2122 NL Konzerte 220712 Afrofuturism
# 7      msg=2223 NL Konzerte 221115 Empfehlungen Dezember
# 8               msg=2122 NL Konzerte 220712 Afrofuturism
# 9               msg=2122 NL Konzerte 220712 Afrofuturism
# 10              msg=2122 NL Konzerte 220712 Afrofuturism
# 11              msg=2122 NL Konzerte 220712 Afrofuturism
# 12     msg=2223 NL Konzerte 221115 Empfehlungen Dezember
# 13     msg=2223 NL Konzerte 221115 Empfehlungen Dezem...
# 14     msg=2223 NL Konzerte 221115 Empfehlungen Dezem...
# ...

# %%
counts = df_neueSpalte.iloc[:, 5:19].apply(pd.Series.value_counts)
print(counts)
# Out:
#                                                      5      6      7     8   \
#                                                     1.0  129.0  579.0  46.0
# bccEmail=                                           NaN    NaN  236.0   NaN
# campaign.id=268018049                               NaN    NaN    3.0   NaN
# campaign.id=268030095                               NaN    NaN    6.0   NaN
# email.messageId=<174363396.250740360.8615728822...  1.0    NaN    NaN   NaN
# ...                                                 ...    ...    ...   ...
# userLanguage=it                                     NaN    1.0    NaN   NaN
# userLanguage=nb                                     NaN    NaN    1.0   NaN
# userLanguage=nl                                     NaN    3.0    1.0   NaN
# userLanguage=sv                                     NaN    2.0    NaN   NaN
# userLanguage=zh                                     NaN    1.0    NaN   NaN
#
# ...

# %%
# Zeilen auswählen, in denen die Werte in der 9. Spalte nicht nur NaN sind
selected_rows = df_neueSpalte[df_neueSpalte.iloc[:, 18].notna()]

# Ergebnis ausgeben
print(selected_rows)
# Out:
#     0                                             1   \
# 281             msg=PVM NDR 2022/23 - Stand 02.08.22
# 341             msg=PVM NDR 2022/23 - Stand 02.08.22
# 579     msg=PVM HHM Konzerte 2022/23 - Stand 7.10.22
# 590             msg=PVM NDR 2022/23 - Stand 02.08.22
# 731             msg=PVM NDR 2022/23 - Stand 02.08.22
# 733             msg=PVM NDR 2022/23 - Stand 02.08.22
# 849     msg=PVM HHM Konzerte 2022/23 - Stand 7.10.22
# 851     msg=PVM HHM Konzerte 2022/23 - Stand 7.10.22
# 907             msg=PVM NDR 2022/23 - Stand 02.08.22
#
#                                      2   \
# 281  event.transactionId=JET_1_a1449855
# 341  event.transactionId=JET_1_a1499498
# 579  event.transactionId=JET_1_a1451468
# 590  event.transactionId=JET_1_a1439348
# 731  event.transactionId=JET_1_a1453730
# 733  event.transactionId=JET_1_a1453818
# 849  event.transactionId=JET_1_a1466602
# 851  event.transactionId=JET_1_a1466598
# 907  event.transactionId=JET_1_a1500058
#
# ...
