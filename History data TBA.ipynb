# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import scipy.stats as stats
import math
import seaborn as sns

# %%
df_transactions_wofirstname = pd.read_csv("C:/Users/felix.oechslein/Desktop/Daten, 13.12.22/Rohdaten/" +
                                    "TBA_transactions_ohne_vorname.csv")
# Out:
# C:\Users\felix.oechslein\AppData\Local\Temp\ipykernel_11364\3938085689.py:1: DtypeWarning: Columns (5,7,8,13,14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_transactions_wofirstname = pd.read_csv("C:/Users/felix.oechslein/Desktop/Daten, 13.12.22/Rohdaten/" +

# %% [markdown]
# # Historiendaten-Betrachtung im Zeitverlauf

# %%
df = df_transactions_wofirstname

# %%
df["createdprovider"] = pd.to_datetime(df['createdprovider'], format='%Y%m%d%H%M%S')
df.set_index('createdprovider', inplace=True)

# %%
df.query("iid == 415355418").tail(50).sort_values("createdprovider")
# Out:
#                       mandator         id        iid attrtype  \
# createdprovider
# 2014-09-02 11:37:31  396091598  448889662  415355418       TI
# 2014-09-02 11:37:31  396091598  448889668  415355418       TI
# 2014-09-02 11:37:31  396091598  448889665  415355418       TI
# 2014-09-02 11:37:31  396091598  448889659  415355418       TI
# 2014-09-02 11:37:32  396091598  448889671  415355418       TI
# 2014-09-02 11:37:32  396091598  448889674  415355418       TI
# 2015-02-10 15:38:40  396091598  449186270  415355418       OR
# 2015-02-10 15:38:40  396091598  449186271  415355418       TI
# 2015-02-10 15:38:40  396091598  449186274  415355418       TI
# 2015-02-10 15:40:14  396091598  449186282  415355418       TI
# 2015-02-10 15:40:14  396091598  449186278  415355418       TI
# 2015-02-10 15:40:14  396091598  449186280  415355418       TI
# 2015-02-10 15:40:14  396091598  449186277  415355418       OR
# 2015-02-10 15:44:01  396091598  449186284  415355418       OR
# ...
